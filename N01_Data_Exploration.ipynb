# %% [markdown]
# # **N1. Data Exploration**

# %% [markdown]
# Notebook focused on analyzing the dataset provided by the Metis Solar Orbiter.

# %% [markdown]
# **Load libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import matplotlib as mpl
from astropy.io import fits
import numpy as np
from libraries.utilities import*

# Plotting configuration.
mpl.rcParams["text.usetex"] = True
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["mathtext.fontset"] = "cm"  

from matplotlib.colors import LogNorm

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1. Data products
#
# For this project, the data provided by the Solar Orbiter Archive consists on a set of FITS (Flexible image transport system) which are store in the repository. Files are divided into the following classes:
#
# 1. Visible Light channel:
#     - Polarized-brightness sequences.
#     - Total-brightness images.
#     - Fixed-polarization images.
#     - Light Curves.
# 2. UV channel:
#     - Analog-mode acquisitions.
#     - Photon-counting acquisitions.
#     - Offset maps.
# 3. Both:
#     - Temporal noise acquisitions.
#     - Cosmic-ray and SEP log matrices.
#
# A detailed description of each data product may be found in the official website. As the main objective is to detect objects in a given image, from now on, only images in the visible light range and ultraviolet range will be taken into account.

# %% [markdown]
# ### 1.2 Levels.
# Obtained FITS files are categorized according to the level of processing as follows:
#
# - Level 0: uncalibrated images packed in standard FITS format.
# - Level 1: uncalibrated images that contain extra engineering data.
# - Level 2: calibrated data in physical units. Corrections are aplied such as: bias, dark-current, flat-flied, vignetting among others. Coordinates are expressed in scientific coordinate systems (WCS)
# - Level 3: data from L2 files with extra scientific analysis.
#
# On the previously mentioned repository, only data from L2 are shown. L0 data was collected later using a package develop that will be explained later. L1 will not be taken into account.

# %% [markdown]
# ### 1.3 Structure.
# Data is stored in LTPs (long-term-planning) with corresponding STPs (short-term-planning). Inside each STP folder, a set of different FITS files may be found.
#
# LTPs values goes from 5 to 17 and STP values from 168 to 340. This configuration represents data acquisition from 2022. It follows the following schema:
#
#         LTP5: STP168, STP169, STP170 ... STP 182
#
#         LTP6: STP 183, STP184, ... STP197
#
#         ...
#
#         LTP17: STP328, ... STP340

# %% [markdown]
# **The data size can be seen in the following plot:**

# %%
# Folder with sources.
DATA_FOLDER = "resources"
# Load .csv with dataset size.
metis_all = pd.read_csv(os.path.join(DATA_FOLDER, "dataset_structure_all.csv")).drop(columns = "Unnamed: 0")
dataset_size = metis_all.groupby("LTP")["FN"].sum().sum()
metis_vl = pd.read_csv(os.path.join(DATA_FOLDER, "dataset_structure_vl.csv")).drop(columns = "Unnamed: 0")
dataset_size_vl = metis_vl.groupby("LTP")["FN"].sum().sum()
metis_uv = pd.read_csv(os.path.join(DATA_FOLDER, "dataset_structure_uv.csv")).drop(columns = "Unnamed: 0")
dataset_size_uv = metis_uv.groupby("LTP")["FN"].sum().sum()

# Create dataframes.
series_vl = pd.DataFrame(metis_vl.groupby("LTP")["FN"].sum())
series_all = pd.DataFrame(metis_all.groupby("LTP")["FN"].sum())
series_uv = pd.DataFrame(metis_uv.groupby("LTP")["FN"].sum())

# %%
# Call figure
plt.figure(figsize = (15,6))
plt.xticks(fontsize = 8)
plt.ylabel("Number of FITS")
plt.title(f"METIS L0 data comparison", fontweight = "bold")

bar_width = 0.3
positions = range(len(series_all))
ticks = np.arange(13)

plt.bar(x=[p - bar_width for p in positions], height= series_all["FN"], width= bar_width, color = "#6a0572", label = f"All FITS: {dataset_size}")
plt.bar( x=positions, height= series_vl["FN"], width= bar_width, color = "#d90368", label = f"Vl images: {dataset_size_vl}")
plt.bar( x=[p + bar_width for p in positions], height= series_uv["FN"],width= bar_width, color = "#f5a31a", label =f"UV images: {dataset_size_uv}")
plt.legend()
plt.xticks(ticks = ticks, labels = ["LTP5", "LTP6", "LTP7", "LTP8", "LTP9", "LTP10", "LTP11", "LTP12", "LTP13", "LTP14", "LTP15", "LTP16", "LTP17"]);

for idx in positions:
    plt.text(idx - bar_width + 0.1, series_all["FN"].iloc[idx] + 0.5, str(series_all["FN"].iloc[idx]), ha="center",
              va="bottom", rotation = 45, fontsize = 9)
    plt.text(idx + 0.1, series_vl["FN"].iloc[idx] + 0.5, str(series_vl["FN"].iloc[idx]), ha="center",
              va="bottom", rotation = 45, fontsize = 9)
    plt.text(idx + bar_width + 0.1, series_uv["FN"].iloc[idx] + 0.5, str(series_uv["FN"].iloc[idx]), ha="center",
              va="bottom", rotation = 45, fontsize = 9)

# %% [markdown]
# ## 2. Data Downloading for L0 images.

# %% [markdown]
# In order to obtain the whole dataset it was developed a package that retrieves all L0 FITS. The pipeline is the following:
#
# 1. Using two  previously defined APIs, retrieve the LTPs and STPs labels.
# 2. Create folders for each one and extract the headers of each file inside every STP folder.
# 3. Merge the headers of a file for obtaining its url to the server.
# 4. Download the content and save it into the folders.
# 5. Create a .csv for files that could not be downloaded.
#
# Additionally, it is possible to download a specific kind of FITS file, for example: vl-image, or uv-image.
#
# **For installing it, run the following commands:**
# 1. Clone the repository:
#    ```bash
#    git clone git@github.com:chioettop/metis_archive_synch.git
#    cd metis_archive_synch
# 2. Install dependencies:
#    ```bash
#    pip install -r requirements.txt
# 3. Run it
#    ```bash
#    python metisdownloader.py

# %% [markdown]
# ## 3. L0 Files

# %% [markdown]
# ### 3.1. Visible light

# %% [markdown]
# Let's analyze the components of FITS L0 image in the visible light bandwidth. It is formed by two files, one with the image and the other one a bin table.

# %%
# Load image
L0_file = os.path.join("resources", "solo_L0_metis-vl-image_0726041008_V01.fits")
L0 = fits.open(L0_file)
# Display components.
L0
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x78f3be83a800>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x78f3be2d2170>]

# %% [markdown]
# #### 3.1.1. Headers

# %% [markdown]
# For this project, just the first component will be taken into account, which is the one that has the image. Let's analyze the headers.

# %%
L0[0].header
# Out:
# SIMPLE  =                    T / file comforms to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 2048 / length of data axis 2
# EXTEND  =                    T / FITS file contains extensions
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L0_metis-vl-image_0726041008_V01.fits' / FITS filename
# FILE_RAW= '2023-01-03T06.33.25.962458Z-VL_IMAGE.raw' / filename of raw data
# APID    =                 1084 / APID number of associated telemetry
# OBT_BEG =    726041008.2422638 / start acquisition time in OBT
# OBT_END =    726042639.9970703 / end acquisition time in OBT
# LEVEL   = 'L0      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = '/asdp/processors/python/l0/3.0.0/L0fits.py' / FITS creation software
# VERS_SW = '3.1.5 | 3.0.0'      / version of SW that provided FITS file
# VERSION =                    1 / incremental version number of FITS file
# INSTRUME= 'Metis   '           / instrument name
# DATAMIN =                    0 / minimum value in data
# DATAMAX =                 5392 / maximum value in data
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=    11.01104174651762 / data compression ratio
# CHECKSUM= '9aEcGYDa9aDaEWDa'   / HDU checksum updated 2023-01-04T00:56:47
# DATASUM = '2574752119'         / data unit checksum updated 2023-01-04T00:56:47
# HISTORY Data acquired during nominal
# HISTORY L0 FITS file created on 2023-01-04T00:56:47.265640
# COMMENT

# %% [markdown]
# The most important parameters are:
# - NAXIS1: the size of the file in the x axis, in this case 2048 pixels.
# - FILENAME: the filename and product. In this case is an image in the visible light range.
# - FILERAW: has the data where the FITS was taken.
# - LEVEL: the preprocessing that the image has, in this case it is the raw version.

# %% [markdown]
# #### 3.1.2. Image
# Now let's plot the image.

# %%
fig, axis = plt.subplots(1, 1, figsize = (5, 5))
axis.imshow(L0[0].data, cmap = "viridis", norm = LogNorm())
axis.set_title(L0[0].header["FILENAME"])
axis.set_xlabel("x detector")
axis.set_ylabel("y detector")
# Out:
# Text(0, 0.5, 'y detector')

# %% [markdown]
# In this image a few things can be seen:
# 1. The dark spot in the center is the plate that protects the sensors onboard the metis from the sun rays.
# 2. In the corners, due to vignetting, it is possible to see the reduction in the brightness of the image.
# 3. Possible stars in the image are not fully visible due to the lack of preprocessing.

# %% [markdown]
# ### 3.2 Ultraviolet band

# %% [markdown]
# Let's analyze the components of FITS L0 image in the ultraviolet bandwidth. It is formed by two files, one with the image and the other one a bin table.

# %%
# Load image
L0_file = os.path.join("resources", "solo_l0_metis-uv-image_0658803566_v01.fits")
L0 = fits.open(L0_file)
# Display components.
L0
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x78f3be2d2140>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x78f3be602800>]

# %% [markdown]
# #### 3.2.1. Headers

# %% [markdown]
# And headers are:

# %%
L0[0].header
# Out:
# SIMPLE  =                    T /  File conforms to FITS standard
# BITPIX  =                   16 / Number of bits per data pixel
# NAXIS   =                    2 / Number of data axes
# NAXIS1  =                 1024 / Number of pixels along axis 1
# NAXIS2  =                 1024 / Number of pixels along axis 2
# EXTEND  =                    T /  File may contain extensions
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_l0_metis-uv-image_0658803566_v01.fits' / FITS filename
# FILE_RAW= '2020-11-16T01.02.50.432893Z-UV_IMAGE.raw' / Filename of raw data
# APID    =                 1084 / APID number of associated telemetry
# OBT_BEG =      658803566.73457 / Start acquisition time in on-board time
# OBT_END =      658803726.42957 / End acquisition time in on-board time
# LEVEL   = 'L0      '           / Data processing level
# ORIGIN  = 'Altec, Italy'       / Location where the FITS file has been generated
# CREATOR = 'metis_l0_prep.pro'  / FITS creation software
# VERS_SW = '1.1.0 | 2.1.1'      / Version of SW that provided FITS file
# VERSION = '01      '           / Incremental version number of FITS file
# INSTRUME= 'Metis   '           / Instrument name
# DATAMIN =                  993 / Minimum value in data
# DATAMAX =                 6084 / Maximum value in data
# BLANK   =               -32768 / Value marking undefined pixels
# COMPRESS= 'Lossless'           / Data compression quality
# COMP_RAT=              1.90422 / Data compression ratio
# DATASUM = '3504975430'         / data unit checksum created 2021-09-22T12:20:46
# CHECKSUM= 'cVEReSBPcSBPcSBP'   / HDU checksum created 2021-09-22T12:20:46
# COMMENT Compression was enabled. The compression header is included
# COMMENT   in the "Metis metadata" extension.
# HISTORY L0 FITS file created on 2021-09-22T12:20:46.48
# HISTORY Data acquired during NECP IT

# %% [markdown]
# The most important parameters are the same listed for the image acquired in the visible light.

# %% [markdown]
# #### 3.2.2. Image

# %%
fig, axis = plt.subplots(1, 1, figsize = (5, 5))
axis.imshow(L0[0].data, cmap = "viridis", norm = LogNorm())
axis.set_title(L0[0].header["FILENAME"])
axis.set_xlabel("x detector")
axis.set_ylabel("y detector")
# Out:
# Text(0, 0.5, 'y detector')

# %% [markdown]
# In this case, there is no visible dark spot for the metis plate that protects against direct solar light. We could also see two interesting points that could be stars or other objects.

# %% [markdown]
# ## 4. L2 Files

# %% [markdown]
# ### 4.1. Visible light

# %% [markdown]
# As it was mentioned before, an L2 image has layers of corrections and processing which enhances the image. The contents are:

# %%
L2_file = os.path.join("resources", "solo_L2_metis-vl-image_20230103T060601_V01.fits")
L2 = fits.open(L2_file)
L2
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x78f3be2d2440>, <astropy.io.fits.hdu.image.ImageHDU object at 0x78f3be6ad210>, <astropy.io.fits.hdu.image.ImageHDU object at 0x78f3be6ad570>]

# %% [markdown]
# Here we have, three file images.

# %% [markdown]
# #### 4.1.1 Headers
# Headers of the first image are:

# %%
L2[0].header
# Out:
# SIMPLE  =                    T / file comforms to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1024 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# EXTEND  =                    T / FITS file contains extensions
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-vl-image_20230103T060601_V01.fits' / FITS filename
# FILE_RAW= '2023-01-03T06.33.25.962458Z-VL_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-vl-image_20230103T060601_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2023-01-12T14:19:58.75' / date and time of FITS file creation
# DATE-OBS= '2023-01-03T06:06:01.874' / same as DATE-BEG
# DATE-BEG= '2023-01-03T06:06:01.874' / start time of observation
# DATE-AVG= '2023-01-03T06:19:37.753' / average time of observation
# DATE-END= '2023-01-03T06:33:13.631' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =    726041008.2422638 / start acquisition time in OBT
# OBT_END =    726042639.9970703 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_vl_generic.pro' / FITS creation software
# VERS_SW = '5.0.0-RC3 | 2.1.1'  / version of SW that provided FITS file
# VERS_CAL= 'LTP10_1.1.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/VLD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'VLD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_SYNOPTIC'     / observation mode
# OBS_TYPE= 'fJXA    '           / encoded version of OBS_MODE
# FILTER  = 'VL      '           / filter used to acquire this image
# WAVELNTH=        610.000000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        580.000000000 / [nm] min. bandpass wavelength
# WAVEMAX =        640.000000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'Visible light'      / bandpass description
# XPOSURE =        420.000000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              1631.75 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_100A_000_000_fJXA_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'VL fixed-polarization intensity' / science data object type
# BUNIT   = 'MSB     '           / units of physical value
# DATAMIN =   -5.77709746508E-07 / minimum value in data
# DATAMAX =    5.54546957512E-08 / maximum value in data
# NBIN1   =                    2 / binning factor in the dimension 1
# NBIN2   =                    2 / binning factor in the dimension 2
# NBIN    =                    4 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                 1024 / last pixel read out in dimension 1
# PXEND2  =                 1024 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=    11.01104174651762 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 1
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '300303  '           / acquisition session number
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Enabled '           / masking flag
# COMPR   = 'Enabled '           / compression flag
# N_POL   =                    4 / number of polarizations used
# FRAMEMOD= 'Single  '           / frame acquisition mode
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# SUNDISK = 'Disabled'           / sun-disk monitor flag
# CME_OBS = 'Disabled'           / CME detection algorithm flag
# MEASKIND= 'pB      '           / measurement kind
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# VLFPFILT= 'Not applicable'     / fixed polarization pre-filter
# PMPSTAB = 'Stable  '           / PMP temperature stability flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# DIT     =                30000 / [ms] detector integration time
# NDIT    =                   14 / number of averaged frames
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.992087348991 / WCS coordinate transformation matrix
# PC1_2   =       0.125549559828 / WCS coordinate transformation matrix
# PC2_1   =      -0.125549559828 / WCS coordinate transformation matrix
# PC2_2   =       0.992087348991 / WCS coordinate transformation matrix
# CDELT1  =        20.2760000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        20.2760000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.21249286981 / [deg] rotation angle
# CRVAL1  =       -177.389653579 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        607.084326662 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              512.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              512.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        524.938607277 / [pixel] sun center location along axis 1
# SUN_YCEN=        483.894284507 / [pixel] sun center location along axis 2
# SUNPIX1 =        524.938607277 / [pixel] sun center location along axis 1
# SUNPIX2 =        483.894284507 / [pixel] sun center location along axis 2
# IO_XCEN =        524.484612350 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        469.986683764 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        524.484612350 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        469.986683764 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              512.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              512.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              512.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              512.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        525.273722628 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        483.894752417 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        525.273722628 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        483.894752417 / [pixel] S/C pointing location along axis 2
# SC_YAW  =        6.74222510995 / [arcsec] S/C HPC yaw
# SC_PITCH=      -0.843671747534 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.13249332170 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1010.43258396 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.60402872276 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        11.7863798857 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.24800507954 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2266.12976346 / carrington rotation number
# HGLT_OBS=        3.60402872276 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -21.7959474918 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.60402872276 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        313.285155677 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142015679462. / [m] S/C distance from sun
# DSUN_AU =       0.949316182093 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        130889576125. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -54136454161.4 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10276984270.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141291589443. / [m] S/C heliocentric inertial x
# HCIY_OBS=        11200222708.8 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8927204326.28 / [m] S/C heliocentric inertial z
# HCIX_VOB=        724.151050496 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20956.0461835 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2462.31668346 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        25064328311.0 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        139408637518. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10269588338.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        131602490964. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -52626444000.7 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8927204326.28 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        16210275889.7 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        54136454161.4 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10277056459.8 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        2218.39753410 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        16.9589741739 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        473.713316237 / [s] time(sun to S/C)
# DATE_EAR= '2023-01-03T06:06:18.83' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2023-01-03T05:58:08.16' / [UTC] obs. start time corrected to sun
# DATATYPE=                    0 / data product type
# REF_ROWS= 'Not included'       / reference rows inclusion flag
# CAD_END = '726042639:65344'    / OBT at cadence end
# SEQ_NUM =                    1 /
# POL_ID  =                    3 / polarization ID
# POLANGLE=              133.200 / [deg] polarization angle
# DAC2POL3=                    0 / [raw] DAC2 for pol. ID 3
# DAC2POL4=                    0 / [raw] DAC2 for pol. ID 4
# DAC2POL1=                 7318 / [raw] DAC2 for pol. ID 0, 1, or 5
# CONF_ID =                    0 / acquisition configuration ID
# DAC2POL2=                    0 / [raw] DAC2 for pol. ID 2 or 6
# DAC1POL1=                 7318 / [raw] DAC1 for pol. ID 0, 1, or 5
# MASKRMAX=                 1440 / [pixel] max. masking radius
# N       =               761836 / number of octects in the data stream
# CADENCE =              7200000 / [ms] acquisition cadence
# OBJ_CNT =                    3 / data object counter
# BIN_TYPE=                    1 / binning type
# CAD_BEG = '726041008:15877'    / OBT at cadence start
# DAC1POL2=                    0 / [raw] DAC1 for pol. ID 2 or 6
# DAC1POL3=                    0 / [raw] DAC1 for pol. ID 3
# IDB_VERS= '4.0     '           /
# HDR_VERS= '5       '           / version of the scientific header
# DAC1POL4=                    0 / [raw] DAC1 for pol. ID 4
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -29.8325017255 / [degC] VLDA temperature
# PMPTEMP =        30.0437914090 / [degC] PMP temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  460 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    1 /
# B0_DQ   =                    0 /
# B0_STOP =                 2048 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= '7GmN89jM7EjM79jM'   / HDU checksum updated 2024-03-26T21:25:23
# DATASUM = '3670096325'         / data unit checksum updated 2024-03-26T21:25:23
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume
# COMMENT Image was rebinned according to the commanded binning factor.
# COMMENT Image values were corrected for the total exposure time.
# COMMENT Uncertainty matrix in the FITS extension is preliminary.
# COMMENT Rotate CROTA degrees counter-clockwise to have Solar North up.
# HISTORY Data acquired during nominal
# HISTORY L0 FITS file created on 2023-01-04T00:56:47.265640
# HISTORY WCS and solar ephemeris:
# HISTORY   SKD version = v107_20220711_001
# HISTORY L1 FITS file created on 2023-01-12T14:19:58.75
# HISTORY Bias and dark-current corrections:
# HISTORY   solo_CAL_metis-vl-bias_20221027a_V00_t.fits
# HISTORY   map_dark_it2_fit_wr.fits
# HISTORY Flat-field correction:
# HISTORY   flat_vlda_JP_15MHZ_MPS_v1.fits
# HISTORY Vignetting correction:
# HISTORY   VF.fits shifted by [0.0, 0.0] pixel
# HISTORY Radiometric calibration:
# HISTORY   cal. factor = 1.48E-15 MSB/DN
# HISTORY   1 MSB = 4.67E+20 ph/cm2/s/sr
# HISTORY Update WCS and solar ephemeris:
# HISTORY   SKD version = v107_20220711_001
# HISTORY L2 FITS file created on 2024-03-26T21:25:21.29

# %% [markdown]
# Most relevant headers are:
# - NAXIS1: The size of the file, in this case 1024 x 1024 pixels.
# - DATE-OBS: Date where observation started.
# - DATE-END: Date where observation ended.
# - WAVELNTH: Characteristic waveband used. Additionally there's info about the wavelengths used as bandpass (min, max).
#
# Other important parameters can be: Position information in different reference frameworks, acquisition time, parameters for corrections, among others.

# %% [markdown]
# Header of second image are:

# %%
L2[1].header
# Out:
# XTENSION= 'IMAGE   '           / image extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1024 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# PCOUNT  =                    0 / parameter count
# GCOUNT  =                    1 / group count
# EXTNAME = 'Quality matrix'     / extension name
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-vl-image_20230103T060601_V01.fits' / FITS filename
# FILE_RAW= '2023-01-03T06.33.25.962458Z-VL_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-vl-image_20230103T060601_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2023-01-12T14:19:58.75' / date and time of FITS file creation
# DATE-OBS= '2023-01-03T06:06:01.874' / same as DATE-BEG
# DATE-BEG= '2023-01-03T06:06:01.874' / start time of observation
# DATE-AVG= '2023-01-03T06:19:37.753' / average time of observation
# DATE-END= '2023-01-03T06:33:13.631' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =    726041008.2422638 / start acquisition time in OBT
# OBT_END =    726042639.9970703 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_vl_generic.pro' / FITS creation software
# VERS_SW = '5.0.0-RC3 | 2.1.1'  / version of SW that provided FITS file
# VERS_CAL= 'LTP10_1.1.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/VLD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'VLD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_SYNOPTIC'     / observation mode
# OBS_TYPE= 'fJXA    '           / encoded version of OBS_MODE
# FILTER  = 'VL      '           / filter used to acquire this image
# WAVELNTH=        610.000000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        580.000000000 / [nm] min. bandpass wavelength
# WAVEMAX =        640.000000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'Visible light'      / bandpass description
# XPOSURE =        420.000000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              1631.75 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_100A_000_000_fJXA_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'Pixel quality'      / science data object type
# BUNIT   = 'None    '           / units of physical value
# DATAMIN =              0.00000 / minimum value in data
# DATAMAX =              1.00000 / maximum value in data
# NBIN1   =                    2 / binning factor in the dimension 1
# NBIN2   =                    2 / binning factor in the dimension 2
# NBIN    =                    4 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                 1024 / last pixel read out in dimension 1
# PXEND2  =                 1024 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=    11.01104174651762 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 1
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '300303  '           / acquisition session number
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Enabled '           / masking flag
# COMPR   = 'Enabled '           / compression flag
# N_POL   =                    4 / number of polarizations used
# FRAMEMOD= 'Single  '           / frame acquisition mode
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# SUNDISK = 'Disabled'           / sun-disk monitor flag
# CME_OBS = 'Disabled'           / CME detection algorithm flag
# MEASKIND= 'pB      '           / measurement kind
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# VLFPFILT= 'Not applicable'     / fixed polarization pre-filter
# PMPSTAB = 'Stable  '           / PMP temperature stability flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# DIT     =                30000 / [ms] detector integration time
# NDIT    =                   14 / number of averaged frames
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.992087348991 / WCS coordinate transformation matrix
# PC1_2   =       0.125549559828 / WCS coordinate transformation matrix
# PC2_1   =      -0.125549559828 / WCS coordinate transformation matrix
# PC2_2   =       0.992087348991 / WCS coordinate transformation matrix
# CDELT1  =        20.2760000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        20.2760000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.21249286981 / [deg] rotation angle
# CRVAL1  =       -177.389653579 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        607.084326662 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              512.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              512.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        524.938607277 / [pixel] sun center location along axis 1
# SUN_YCEN=        483.894284507 / [pixel] sun center location along axis 2
# SUNPIX1 =        524.938607277 / [pixel] sun center location along axis 1
# SUNPIX2 =        483.894284507 / [pixel] sun center location along axis 2
# IO_XCEN =        524.484612350 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        469.986683764 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        524.484612350 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        469.986683764 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              512.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              512.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              512.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              512.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        525.273722628 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        483.894752417 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        525.273722628 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        483.894752417 / [pixel] S/C pointing location along axis 2
# SC_YAW  =        6.74222510995 / [arcsec] S/C HPC yaw
# SC_PITCH=      -0.843671747534 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.13249332170 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1010.43258396 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.60402872276 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        11.7863798857 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.24800507954 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2266.12976346 / carrington rotation number
# HGLT_OBS=        3.60402872276 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -21.7959474918 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.60402872276 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        313.285155677 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142015679462. / [m] S/C distance from sun
# DSUN_AU =       0.949316182093 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        130889576125. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -54136454161.4 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10276984270.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141291589443. / [m] S/C heliocentric inertial x
# HCIY_OBS=        11200222708.8 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8927204326.28 / [m] S/C heliocentric inertial z
# HCIX_VOB=        724.151050496 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20956.0461835 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2462.31668346 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        25064328311.0 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        139408637518. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10269588338.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        131602490964. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -52626444000.7 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8927204326.28 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        16210275889.7 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        54136454161.4 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10277056459.8 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        2218.39753410 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        16.9589741739 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        473.713316237 / [s] time(sun to S/C)
# DATE_EAR= '2023-01-03T06:06:18.83' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2023-01-03T05:58:08.16' / [UTC] obs. start time corrected to sun
# DATATYPE=                    0 / data product type
# REF_ROWS= 'Not included'       / reference rows inclusion flag
# CAD_END = '726042639:65344'    / OBT at cadence end
# SEQ_NUM =                    1 /
# POL_ID  =                    3 / polarization ID
# POLANGLE=              133.200 / [deg] polarization angle
# DAC2POL3=                    0 / [raw] DAC2 for pol. ID 3
# DAC2POL4=                    0 / [raw] DAC2 for pol. ID 4
# DAC2POL1=                 7318 / [raw] DAC2 for pol. ID 0, 1, or 5
# CONF_ID =                    0 / acquisition configuration ID
# DAC2POL2=                    0 / [raw] DAC2 for pol. ID 2 or 6
# DAC1POL1=                 7318 / [raw] DAC1 for pol. ID 0, 1, or 5
# MASKRMAX=                 1440 / [pixel] max. masking radius
# N       =               761836 / number of octects in the data stream
# CADENCE =              7200000 / [ms] acquisition cadence
# OBJ_CNT =                    3 / data object counter
# BIN_TYPE=                    1 / binning type
# CAD_BEG = '726041008:15877'    / OBT at cadence start
# DAC1POL2=                    0 / [raw] DAC1 for pol. ID 2 or 6
# DAC1POL3=                    0 / [raw] DAC1 for pol. ID 3
# IDB_VERS= '4.0     '           /
# HDR_VERS= '5       '           / version of the scientific header
# DAC1POL4=                    0 / [raw] DAC1 for pol. ID 4
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -29.8325017255 / [degC] VLDA temperature
# PMPTEMP =        30.0437914090 / [degC] PMP temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  460 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    1 /
# B0_DQ   =                    0 /
# B0_STOP =                 2048 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= 'NaQcOVQZNZQbNZQZ'   / HDU checksum updated 2024-03-26T21:25:23
# DATASUM = '3120766045'         / data unit checksum updated 2024-03-26T21:25:23
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume
# COMMENT Quality matrix values:
# COMMENT   NaN = saturated or null L0 pixel counts
# COMMENT   0   = unreliable pixel value
# COMMENT   1   = good pixel

# %% [markdown]
# Headers of third image are:

# %%
L2[2].header
# Out:
# XTENSION= 'IMAGE   '           / image extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1024 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# PCOUNT  =                    0 / parameter count
# GCOUNT  =                    1 / group count
# EXTNAME = 'Error matrix'       / extension name
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-vl-image_20230103T060601_V01.fits' / FITS filename
# FILE_RAW= '2023-01-03T06.33.25.962458Z-VL_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-vl-image_20230103T060601_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2023-01-12T14:19:58.75' / date and time of FITS file creation
# DATE-OBS= '2023-01-03T06:06:01.874' / same as DATE-BEG
# DATE-BEG= '2023-01-03T06:06:01.874' / start time of observation
# DATE-AVG= '2023-01-03T06:19:37.753' / average time of observation
# DATE-END= '2023-01-03T06:33:13.631' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =    726041008.2422638 / start acquisition time in OBT
# OBT_END =    726042639.9970703 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_vl_generic.pro' / FITS creation software
# VERS_SW = '5.0.0-RC3 | 2.1.1'  / version of SW that provided FITS file
# VERS_CAL= 'LTP10_1.1.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/VLD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'VLD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_SYNOPTIC'     / observation mode
# OBS_TYPE= 'fJXA    '           / encoded version of OBS_MODE
# FILTER  = 'VL      '           / filter used to acquire this image
# WAVELNTH=        610.000000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        580.000000000 / [nm] min. bandpass wavelength
# WAVEMAX =        640.000000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'Visible light'      / bandpass description
# XPOSURE =        420.000000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              1631.75 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_100A_000_000_fJXA_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'Absolute error'     / science data object type
# BUNIT   = 'MSB     '           / units of physical value
# DATAMIN =   -3.86390756221E-05 / minimum value in data
# DATAMAX =    6.85428072437E-06 / maximum value in data
# NBIN1   =                    2 / binning factor in the dimension 1
# NBIN2   =                    2 / binning factor in the dimension 2
# NBIN    =                    4 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                 1024 / last pixel read out in dimension 1
# PXEND2  =                 1024 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=    11.01104174651762 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 1
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '300303  '           / acquisition session number
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Enabled '           / masking flag
# COMPR   = 'Enabled '           / compression flag
# N_POL   =                    4 / number of polarizations used
# FRAMEMOD= 'Single  '           / frame acquisition mode
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# SUNDISK = 'Disabled'           / sun-disk monitor flag
# CME_OBS = 'Disabled'           / CME detection algorithm flag
# MEASKIND= 'pB      '           / measurement kind
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# VLFPFILT= 'Not applicable'     / fixed polarization pre-filter
# PMPSTAB = 'Stable  '           / PMP temperature stability flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# DIT     =                30000 / [ms] detector integration time
# NDIT    =                   14 / number of averaged frames
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.992087348991 / WCS coordinate transformation matrix
# PC1_2   =       0.125549559828 / WCS coordinate transformation matrix
# PC2_1   =      -0.125549559828 / WCS coordinate transformation matrix
# PC2_2   =       0.992087348991 / WCS coordinate transformation matrix
# CDELT1  =        20.2760000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        20.2760000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.21249286981 / [deg] rotation angle
# CRVAL1  =       -177.389653579 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        607.084326662 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              512.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              512.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        524.938607277 / [pixel] sun center location along axis 1
# SUN_YCEN=        483.894284507 / [pixel] sun center location along axis 2
# SUNPIX1 =        524.938607277 / [pixel] sun center location along axis 1
# SUNPIX2 =        483.894284507 / [pixel] sun center location along axis 2
# IO_XCEN =        524.484612350 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        469.986683764 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        524.484612350 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        469.986683764 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              512.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              512.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              512.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              512.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        525.273722628 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        483.894752417 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        525.273722628 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        483.894752417 / [pixel] S/C pointing location along axis 2
# SC_YAW  =        6.74222510995 / [arcsec] S/C HPC yaw
# SC_PITCH=      -0.843671747534 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.13249332170 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1010.43258396 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.60402872276 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        11.7863798857 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.24800507954 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2266.12976346 / carrington rotation number
# HGLT_OBS=        3.60402872276 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -21.7959474918 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.60402872276 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        313.285155677 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142015679462. / [m] S/C distance from sun
# DSUN_AU =       0.949316182093 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        130889576125. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -54136454161.4 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10276984270.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141291589443. / [m] S/C heliocentric inertial x
# HCIY_OBS=        11200222708.8 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8927204326.28 / [m] S/C heliocentric inertial z
# HCIX_VOB=        724.151050496 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20956.0461835 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2462.31668346 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        25064328311.0 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        139408637518. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10269588338.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        131602490964. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -52626444000.7 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8927204326.28 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        16210275889.7 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        54136454161.4 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10277056459.8 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        2218.39753410 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        16.9589741739 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        473.713316237 / [s] time(sun to S/C)
# DATE_EAR= '2023-01-03T06:06:18.83' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2023-01-03T05:58:08.16' / [UTC] obs. start time corrected to sun
# DATATYPE=                    0 / data product type
# REF_ROWS= 'Not included'       / reference rows inclusion flag
# CAD_END = '726042639:65344'    / OBT at cadence end
# SEQ_NUM =                    1 /
# POL_ID  =                    3 / polarization ID
# POLANGLE=              133.200 / [deg] polarization angle
# DAC2POL3=                    0 / [raw] DAC2 for pol. ID 3
# DAC2POL4=                    0 / [raw] DAC2 for pol. ID 4
# DAC2POL1=                 7318 / [raw] DAC2 for pol. ID 0, 1, or 5
# CONF_ID =                    0 / acquisition configuration ID
# DAC2POL2=                    0 / [raw] DAC2 for pol. ID 2 or 6
# DAC1POL1=                 7318 / [raw] DAC1 for pol. ID 0, 1, or 5
# MASKRMAX=                 1440 / [pixel] max. masking radius
# N       =               761836 / number of octects in the data stream
# CADENCE =              7200000 / [ms] acquisition cadence
# OBJ_CNT =                    3 / data object counter
# BIN_TYPE=                    1 / binning type
# CAD_BEG = '726041008:15877'    / OBT at cadence start
# DAC1POL2=                    0 / [raw] DAC1 for pol. ID 2 or 6
# DAC1POL3=                    0 / [raw] DAC1 for pol. ID 3
# IDB_VERS= '4.0     '           /
# HDR_VERS= '5       '           / version of the scientific header
# DAC1POL4=                    0 / [raw] DAC1 for pol. ID 4
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -29.8325017255 / [degC] VLDA temperature
# PMPTEMP =        30.0437914090 / [degC] PMP temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  460 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    1 /
# B0_DQ   =                    0 /
# B0_STOP =                 2048 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= 'k2gek1Zck1dck1Zc'   / HDU checksum updated 2024-03-26T21:25:23
# DATASUM = '1190895527'         / data unit checksum updated 2024-03-26T21:25:23
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume

# %% [markdown]
# #### 4.1.2. Images
# The three images in the file are:

# %%
fig, axis =  plt.subplots(1, 3, figsize = (14, 5))
fig.supxlabel("x detector")
fig.supylabel("y detector")
fig.suptitle(f"L2 FITS file: {L2[0].header['FILENAME']}")

axis[0].imshow(L2[0].data, norm = LogNorm() )
axis[0].set_title("Visible-light range image")
axis[1].imshow(L2[1].data )
axis[1].set_title("Quality matrix")
axis[2].imshow(L2[2].data, norm = LogNorm() )
axis[2].set_title("Error matrix")
plt.tight_layout()

# %% [markdown]
# Labels were extracted in the header called: "extension". Here we will only focus on the image itself and not in the quality matrix or the error matrix.

# %% [markdown]
# ### 4.2 Ultraviolet bandwidth

# %% [markdown]
# The FITS L2 in the uv range is:

# %%
L2_file = os.path.join("resources", "solo_L2_metis-uv-image_20240101T060007_V01.fits")
L2 = fits.open(L2_file)
# Display components.
L2
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x78f3be6ad2d0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x78f3be461db0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x78f3be462110>]

# %% [markdown]
# Here we also have three images.

# %% [markdown]
# #### 4.2.1. Headers

# %% [markdown]
# The headers are:
#
# For the first image:

# %%
L2[0].header
# Out:
# SIMPLE  =                    T / file comforms to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  256 / length of data axis 1
# NAXIS2  =                  256 / length of data axis 2
# EXTEND  =                    T / FITS file contains extensions
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-uv-image_20240101T060007_V01.fits' / FITS filename
# FILE_RAW= '2024-01-01T06.07.26.092725Z-UV_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-uv-image_20240101T060007_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2024-02-08T03:19:17.96' / date and time of FITS file creation
# DATE-OBS= '2024-01-01T06:00:07.396' / same as DATE-BEG
# DATE-BEG= '2024-01-01T06:00:07.396' / start time of observation
# DATE-AVG= '2024-01-01T06:03:45.679' / average time of observation
# DATE-END= '2024-01-01T06:07:23.962' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =     757403796.997345 / start acquisition time in OBT
# OBT_END =    757404233.5619659 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_uv.pro' / FITS creation software
# VERS_SW = 'l2-dev  '           / version of SW that provided FITS file
# VERS_CAL= 'LTP14_1.0.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/UVD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'UVD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_UV_RC'        / observation mode
# OBS_TYPE= 'pChg    '           / encoded version of OBS_MODE
# FILTER  = 'UV      '           / filter used to acquire this image
# WAVELNTH=        121.600000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        111.600000000 / [nm] min. bandpass wavelength
# WAVEMAX =        131.600000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'H I Lyman-alpha'    / bandpass description
# XPOSURE =        419.118000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              436.565 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_140A_000_000_pChg_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'UV Lyman-alpha intensity' / science data object type
# BUNIT   = 'ph/cm2/s/sr'        / units of physical value
# DATAMIN =       -19700012563.3 / minimum value in data
# DATAMAX =    1.85906698115E+13 / maximum value in data
# NBIN1   =                    4 / binning factor in the dimension 1
# NBIN2   =                    4 / binning factor in the dimension 2
# NBIN    =                   16 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                  256 / last pixel read out in dimension 1
# PXEND2  =                  256 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=     37.0181458730495 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 5
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '400106  '           / acquisition session number
# HVU_MCP =        0.00000000000 / [raw] HVU MCP commanded voltage
# HV_SCR_V=        0.00000000000 / [V] HVU Screen + MCP read voltage
# HV_MCP_V=        0.00000000000 / [V] HVU MCP read voltage
# HV_MCP_I=        0.00000000000 / [uA] HVU MCP current
# HV_TEMP =        0.00000000000 / [degC] HVU temperature
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Disabled'           / masking flag
# COMPR   = 'Enabled '           / compression flag
# BIN_TYPE=                    2 / binning type
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# PRESUM  = 'Disabled'           / presum algorithm flag
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# HVU_SCR =        0.00000000000 / [raw] HVU Screen commanded voltage
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# NDIT2   =                   14 / number of averaged frames
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# NDIT1   =                    1 / number of hardware-averaged frames
# DIT     =                29937 / [ms] detector integration time
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.991737734533 / WCS coordinate transformation matrix
# PC1_2   =       0.128281978090 / WCS coordinate transformation matrix
# PC2_1   =      -0.128281978090 / WCS coordinate transformation matrix
# PC2_2   =       0.991737734533 / WCS coordinate transformation matrix
# CDELT1  =        81.6000000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        81.6000000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.37032525940 / [deg] rotation angle
# CRVAL1  =       -42.6965684309 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        89.7752722341 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              128.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              128.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        129.160053279 / [pixel] sun center location along axis 1
# SUN_YCEN=        127.476025431 / [pixel] sun center location along axis 2
# SUNPIX1 =        129.160053279 / [pixel] sun center location along axis 1
# SUNPIX2 =        127.476025431 / [pixel] sun center location along axis 2
# IO_XCEN =        128.965686275 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        124.026960784 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        128.965686275 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        124.026960784 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              128.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              128.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              128.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              128.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        129.161764706 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        127.482843137 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        129.161764706 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        127.482843137 / [pixel] S/C pointing location along axis 2
# SC_YAW  =       0.209865052419 / [arcsec] S/C HPC yaw
# SC_PITCH=       0.533813450935 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.29032572117 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1006.76484221 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.29094977623 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        10.6352843566 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.21565141559 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2279.42493902 / carrington rotation number
# HGLT_OBS=        3.29094977623 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -16.9805601114 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.29094977623 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        207.021952092 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142533064587. / [m] S/C distance from sun
# DSUN_AU =       0.952774688039 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        135487781960. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -43035363488.6 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10329226967.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141222137116. / [m] S/C heliocentric inertial x
# HCIY_OBS=        17465178183.5 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8182300420.94 / [m] S/C heliocentric inertial z
# HCIX_VOB=       -1229.51172712 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20757.3416783 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2582.78528728 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        18932069286.7 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        140892578567. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10321461039.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        136094374412. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -41557739519.1 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8182300420.94 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        11614145495.6 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        43035363488.6 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10329651874.1 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        1177.01301559 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        15.2400860879 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        475.439127249 / [s] time(sun to S/C)
# DATE_EAR= '2024-01-01T06:00:22.63' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2024-01-01T05:52:11.95' / [UTC] obs. start time corrected to sun
# DATATYPE=                    1 / data product type
# CAD_END = '757404233:36829'    / OBT at cadence end
# CONF_ID =                    0 / acquisition configuration ID
# MASKRMAX=                  640 / [pixel] max. masking radius
# N       =                56652 / number of octects in the data stream
# CADENCE =               900000 / [ms] acquisition cadence
# OBJ_CNT =                    7 / data object counter
# CAD_BEG = '757403796:65362'    / OBT at cadence start
# IDB_VERS= '        '           /
# HDR_VERS= '5       '           / version of the scientific header
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -26.1163005829 / [degC] UVDA temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  264 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    2 /
# B0_DQ   =                    0 /
# B0_STOP =                 1024 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= 'XFIJYEHGXEHGXEHG'   / HDU checksum updated 2024-05-22T07:20:28
# DATASUM = '3707676951'         / data unit checksum updated 2024-05-22T07:20:28
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume
# COMMENT Image was rebinned according to the commanded binning factor.
# COMMENT Image values were corrected for the total exposure time.
# COMMENT WARNING: UV radiometric calibration is still preliminary.
# COMMENT Uncertainty matrix in the FITS extension is preliminary.
# COMMENT Rotate CROTA degrees counter-clockwise to have Solar North up.
# HISTORY Data acquired during nominal
# HISTORY L0 FITS file created on 2024-01-02T04:12:07.702233
# HISTORY WCS and solar ephemeris:
# HISTORY   SKD version = v110_20231113_001
# HISTORY L1 FITS file created on 2024-02-08T03:19:17.96
# HISTORY Dark-current correction:
# HISTORY   Dark_UVDA_STP281_29937ms_NDIT1-1_NDIT2-1.fits
# HISTORY   extrapolated dark = false
# HISTORY   corrected dark = true
# HISTORY     offset = -3.3 DN
# HISTORY Flat-field correction:
# HISTORY   FF_UVDA_LYA_20160701_bin=4.fits
# HISTORY Vignetting correction:
# HISTORY   VF.fits shifted by [-20.2, 49.0] pixel
# HISTORY Radiometric calibration:
# HISTORY   efficiency corr. map = UVRC2_eff_map_det_v01.fits
# HISTORY Update WCS and solar ephemeris:
# HISTORY   SKD version = v111_20240508_002
# HISTORY L2 FITS file created on 2024-05-22T07:20:27.44

# %% [markdown]
# For the second one:

# %%
L2[1].header
# Out:
# XTENSION= 'IMAGE   '           / image extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  256 / length of data axis 1
# NAXIS2  =                  256 / length of data axis 2
# PCOUNT  =                    0 / parameter count
# GCOUNT  =                    1 / group count
# EXTNAME = 'Quality matrix'     / extension name
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-uv-image_20240101T060007_V01.fits' / FITS filename
# FILE_RAW= '2024-01-01T06.07.26.092725Z-UV_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-uv-image_20240101T060007_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2024-02-08T03:19:17.96' / date and time of FITS file creation
# DATE-OBS= '2024-01-01T06:00:07.396' / same as DATE-BEG
# DATE-BEG= '2024-01-01T06:00:07.396' / start time of observation
# DATE-AVG= '2024-01-01T06:03:45.679' / average time of observation
# DATE-END= '2024-01-01T06:07:23.962' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =     757403796.997345 / start acquisition time in OBT
# OBT_END =    757404233.5619659 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_uv.pro' / FITS creation software
# VERS_SW = 'l2-dev  '           / version of SW that provided FITS file
# VERS_CAL= 'LTP14_1.0.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/UVD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'UVD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_UV_RC'        / observation mode
# OBS_TYPE= 'pChg    '           / encoded version of OBS_MODE
# FILTER  = 'UV      '           / filter used to acquire this image
# WAVELNTH=        121.600000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        111.600000000 / [nm] min. bandpass wavelength
# WAVEMAX =        131.600000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'H I Lyman-alpha'    / bandpass description
# XPOSURE =        419.118000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              436.565 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_140A_000_000_pChg_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'Pixel quality'      / science data object type
# BUNIT   = 'None    '           / units of physical value
# DATAMIN =              0.00000 / minimum value in data
# DATAMAX =              1.00000 / maximum value in data
# NBIN1   =                    4 / binning factor in the dimension 1
# NBIN2   =                    4 / binning factor in the dimension 2
# NBIN    =                   16 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                  256 / last pixel read out in dimension 1
# PXEND2  =                  256 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=     37.0181458730495 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 5
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '400106  '           / acquisition session number
# HVU_MCP =        0.00000000000 / [raw] HVU MCP commanded voltage
# HV_SCR_V=        0.00000000000 / [V] HVU Screen + MCP read voltage
# HV_MCP_V=        0.00000000000 / [V] HVU MCP read voltage
# HV_MCP_I=        0.00000000000 / [uA] HVU MCP current
# HV_TEMP =        0.00000000000 / [degC] HVU temperature
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Disabled'           / masking flag
# COMPR   = 'Enabled '           / compression flag
# BIN_TYPE=                    2 / binning type
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# PRESUM  = 'Disabled'           / presum algorithm flag
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# HVU_SCR =        0.00000000000 / [raw] HVU Screen commanded voltage
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# NDIT2   =                   14 / number of averaged frames
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# NDIT1   =                    1 / number of hardware-averaged frames
# DIT     =                29937 / [ms] detector integration time
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.991737734533 / WCS coordinate transformation matrix
# PC1_2   =       0.128281978090 / WCS coordinate transformation matrix
# PC2_1   =      -0.128281978090 / WCS coordinate transformation matrix
# PC2_2   =       0.991737734533 / WCS coordinate transformation matrix
# CDELT1  =        81.6000000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        81.6000000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.37032525940 / [deg] rotation angle
# CRVAL1  =       -42.6965684309 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        89.7752722341 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              128.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              128.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        129.160053279 / [pixel] sun center location along axis 1
# SUN_YCEN=        127.476025431 / [pixel] sun center location along axis 2
# SUNPIX1 =        129.160053279 / [pixel] sun center location along axis 1
# SUNPIX2 =        127.476025431 / [pixel] sun center location along axis 2
# IO_XCEN =        128.965686275 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        124.026960784 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        128.965686275 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        124.026960784 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              128.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              128.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              128.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              128.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        129.161764706 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        127.482843137 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        129.161764706 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        127.482843137 / [pixel] S/C pointing location along axis 2
# SC_YAW  =       0.209865052419 / [arcsec] S/C HPC yaw
# SC_PITCH=       0.533813450935 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.29032572117 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1006.76484221 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.29094977623 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        10.6352843566 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.21565141559 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2279.42493902 / carrington rotation number
# HGLT_OBS=        3.29094977623 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -16.9805601114 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.29094977623 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        207.021952092 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142533064587. / [m] S/C distance from sun
# DSUN_AU =       0.952774688039 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        135487781960. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -43035363488.6 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10329226967.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141222137116. / [m] S/C heliocentric inertial x
# HCIY_OBS=        17465178183.5 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8182300420.94 / [m] S/C heliocentric inertial z
# HCIX_VOB=       -1229.51172712 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20757.3416783 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2582.78528728 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        18932069286.7 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        140892578567. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10321461039.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        136094374412. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -41557739519.1 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8182300420.94 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        11614145495.6 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        43035363488.6 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10329651874.1 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        1177.01301559 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        15.2400860879 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        475.439127249 / [s] time(sun to S/C)
# DATE_EAR= '2024-01-01T06:00:22.63' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2024-01-01T05:52:11.95' / [UTC] obs. start time corrected to sun
# DATATYPE=                    1 / data product type
# CAD_END = '757404233:36829'    / OBT at cadence end
# CONF_ID =                    0 / acquisition configuration ID
# MASKRMAX=                  640 / [pixel] max. masking radius
# N       =                56652 / number of octects in the data stream
# CADENCE =               900000 / [ms] acquisition cadence
# OBJ_CNT =                    7 / data object counter
# CAD_BEG = '757403796:65362'    / OBT at cadence start
# IDB_VERS= '        '           /
# HDR_VERS= '5       '           / version of the scientific header
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -26.1163005829 / [degC] UVDA temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  264 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    2 /
# B0_DQ   =                    0 /
# B0_STOP =                 1024 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= '6Q267O256O256O25'   / HDU checksum updated 2024-05-22T07:20:28
# DATASUM = '763375148'          / data unit checksum updated 2024-05-22T07:20:28
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume
# COMMENT Quality matrix values:
# COMMENT   NaN = saturated or null L0 pixel counts
# COMMENT   0   = unreliable pixel value
# COMMENT   1   = good pixel

# %% [markdown]
# For the last image:

# %%
L2[2].header
# Out:
# XTENSION= 'IMAGE   '           / image extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  256 / length of data axis 1
# NAXIS2  =                  256 / length of data axis 2
# PCOUNT  =                    0 / parameter count
# GCOUNT  =                    1 / group count
# EXTNAME = 'Error matrix'       / extension name
# LONGSTRN= 'OGIP 1.0'           / FITS header contains long strings
# FILENAME= 'solo_L2_metis-uv-image_20240101T060007_V01.fits' / FITS filename
# FILE_RAW= '2024-01-01T06.07.26.092725Z-UV_IMAGE.raw' / filename of raw data
# PARENT  = 'solo_L1_metis-uv-image_20240101T060007_V01.fits' / name of the parent
# APID    =                 1084 / APID number of associated telemetry
# DATE    = '2024-02-08T03:19:17.96' / date and time of FITS file creation
# DATE-OBS= '2024-01-01T06:00:07.396' / same as DATE-BEG
# DATE-BEG= '2024-01-01T06:00:07.396' / start time of observation
# DATE-AVG= '2024-01-01T06:03:45.679' / average time of observation
# DATE-END= '2024-01-01T06:07:23.962' / end time of observation
# TIMESYS = 'UTC     '           / system used for time keywords
# TIMRDER =              0.00000 / [s] estimated random error in time values
# TIMSYER =              0.00000 / [s] estimated systematic error in time values
# OBT_BEG =     757403796.997345 / start acquisition time in OBT
# OBT_END =    757404233.5619659 / end acquisition time in OBT
# LEVEL   = 'L2      '           / data processing level
# ORIGIN  = 'Metis EGSE'         / location where the FITS file has been generated
# CREATOR = 'metis_l2_prep_uv.pro' / FITS creation software
# VERS_SW = 'l2-dev  '           / version of SW that provided FITS file
# VERS_CAL= 'LTP14_1.0.0'        / version of the calibration package
# VERSION = '01      '           / incremental version number of FITS file
# OBSRVTRY= 'Solar Orbiter'      / satellite name
# TELESCOP= 'SOLO/Metis/UVD'     / telescope that took the measurement
# INSTRUME= 'Metis   '           / instrument name
# DETECTOR= 'UVD     '           / subunit/sensor
# OBJECT  = 'Sun     '           / the use of the keyword OBJECT is [TBD]
# OBS_MODE= 'METIS_UV_RC'        / observation mode
# OBS_TYPE= 'pChg    '           / encoded version of OBS_MODE
# FILTER  = 'UV      '           / filter used to acquire this image
# WAVELNTH=        121.600000000 / [nm] characteristic wavelength of observation
# WAVEMIN =        111.600000000 / [nm] min. bandpass wavelength
# WAVEMAX =        131.600000000 / [nm] max. bandpass wavelength
# WAVEBAND= 'H I Lyman-alpha'    / bandpass description
# XPOSURE =        419.118000000 / [s] total effective exposure time
# NSUMEXP =                   14 / number of detector readouts summed together
# TELAPSE =              436.565 / [s] elapsed time during observation
# SOOPNAME= 'none    '           / name of the SOOP that the data belong to
# SOOPTYPE= 'none    '           / campaign ID(s) that the data belong to
# OBS_ID  = 'SMET_140A_000_000_pChg_111' / unique ID of the individual observation
# TARGET  = 'Corona  '           / type of target from planning
# BSCALE  =                    1 / ratio of physical to array value at 0 offset
# BZERO   =                    0 / physical value for the array value 0
# BTYPE   = 'Absolute error'     / science data object type
# BUNIT   = 'ph/cm2/s/sr'        / units of physical value
# DATAMIN =       -4455829699.47 / minimum value in data
# DATAMAX =    1.74798399769E+16 / maximum value in data
# NBIN1   =                    4 / binning factor in the dimension 1
# NBIN2   =                    4 / binning factor in the dimension 2
# NBIN    =                   16 / product of all NBIN values above
# PXBEG1  =                    1 / first pixel read out in dimension 1
# PXBEG2  =                    1 / first pixel read out in dimension 2
# PXEND1  =                  256 / last pixel read out in dimension 1
# PXEND2  =                  256 / last pixel read out in dimension 2
# COMPRESS= 'lossless'           / data compression quality
# COMP_RAT=     37.0181458730495 / data compression ratio
# SN_VAR5 =              0.00000 / spatial-noise variance in region 5
# SN_VAR4 =              0.00000 / spatial-noise variance in region 4
# SN_VAR3 =              0.00000 / spatial-noise variance in region 3
# SN_MEAN1=                    0 / spatial-noise mean in region 1
# SN_MEAN2=                    0 / spatial-noise mean in region 2
# SN_MEAN3=                    0 / spatial-noise mean in region 3
# SN_MEAN4=                    0 / spatial-noise mean in region 4
# SN_MEAN5=                    0 / spatial-noise mean in region 5
# SN_VAR2 =              0.00000 / spatial-noise variance in region 2
# SN_VAR1 =              0.00000 / spatial-noise variance in region 1
# SESS_NUM= '400106  '           / acquisition session number
# HVU_MCP =        0.00000000000 / [raw] HVU MCP commanded voltage
# HV_SCR_V=        0.00000000000 / [V] HVU Screen + MCP read voltage
# HV_MCP_V=        0.00000000000 / [V] HVU MCP read voltage
# HV_MCP_I=        0.00000000000 / [uA] HVU MCP current
# HV_TEMP =        0.00000000000 / [degC] HVU temperature
# RADIAL  = 'Disabled'           / radialization flag
# MASKING = 'Disabled'           / masking flag
# COMPR   = 'Enabled '           / compression flag
# BIN_TYPE=                    2 / binning type
# SP_NOISE= 'Disabled'           / spatial-noise algorithm flag
# PRESUM  = 'Disabled'           / presum algorithm flag
# CR_SEP  = 'Disabled'           / CR/SEP algorithm flag
# CR_SEP_B=              0.00000 / CR/SEP algorithm param. B
# HVU_SCR =        0.00000000000 / [raw] HVU Screen commanded voltage
# CR_SEP_A=              0.00000 / CR/SEP algorithm param. A
# NDIT2   =                   14 / number of averaged frames
# SNRMAX  =                    0 / [pixel] max. radius for spatial-noise algo
# NDIT1   =                    1 / number of hardware-averaged frames
# DIT     =                29937 / [ms] detector integration time
# WCSNAME = 'Helioprojective-Cartesian' / name of coordinate system
# CTYPE1  = 'HPLN-TAN'           / helioprojective longitude (solar x)
# CTYPE2  = 'HPLT-TAN'           / helioprojective latitude (solar y)
# CUNIT1  = 'arcsec  '           / units along axis 1
# CUNIT2  = 'arcsec  '           / units along axis 2
# PC1_1   =       0.991737734533 / WCS coordinate transformation matrix
# PC1_2   =       0.128281978090 / WCS coordinate transformation matrix
# PC2_1   =      -0.128281978090 / WCS coordinate transformation matrix
# PC2_2   =       0.991737734533 / WCS coordinate transformation matrix
# CDELT1  =        81.6000000000 / [arcsec] pixel scale along axis 1
# CDELT2  =        81.6000000000 / [arcsec] pixel scale along axis 2
# CROTA   =       -7.37032525940 / [deg] rotation angle
# CRVAL1  =       -42.6965684309 / [arcsec] value of reference pixel along axis 1
# CRVAL2  =        89.7752722341 / [arcsec] value of reference pixel along axis 2
# CRPIX1  =              128.500 / [pixel] reference pixel location along axis 1
# CRPIX2  =              128.500 / [pixel] reference pixel location along axis 2
# SUN_XCEN=        129.160053279 / [pixel] sun center location along axis 1
# SUN_YCEN=        127.476025431 / [pixel] sun center location along axis 2
# SUNPIX1 =        129.160053279 / [pixel] sun center location along axis 1
# SUNPIX2 =        127.476025431 / [pixel] sun center location along axis 2
# IO_XCEN =        128.965686275 / [pixel] Metis IO center location along axis 1
# IO_YCEN =        124.026960784 / [pixel] Metis IO center location along axis 2
# IOPIX1  =        128.965686275 / [pixel] Metis IO center location along axis 1
# IOPIX2  =        124.026960784 / [pixel] Metis IO center location along axis 2
# FS_XCEN =              128.500 / [pixel] Metis FS center location along axis 1
# FS_YCEN =              128.500 / [pixel] Metis FS center location along axis 2
# FSPIX1  =              128.500 / [pixel] Metis FS center location along axis 1
# FSPIX2  =              128.500 / [pixel] Metis FS center location along axis 2
# SC_XCEN =        129.161764706 / [pixel] S/C pointing location along axis 1
# SC_YCEN =        127.482843137 / [pixel] S/C pointing location along axis 2
# SCPIX1  =        129.161764706 / [pixel] S/C pointing location along axis 1
# SCPIX2  =        127.482843137 / [pixel] S/C pointing location along axis 2
# SC_YAW  =       0.209865052419 / [arcsec] S/C HPC yaw
# SC_PITCH=       0.533813450935 / [arcsec] S/C HPC pitch
# SC_ROLL =       -7.29032572117 / [deg] S/C HPC roll angle
# INN_FOV =              1.60000 / [deg] inner Metis FOV
# OUT_FOV =              3.40000 / [deg] outer Metis FOV
# LONPOLE =              180.000 / [deg] native longitude of the celestial pole
# RSUN_ARC=        1006.76484221 / [arcsec] apparent photospheric solar radius
# RSUN_REF=        695700000.000 / [m] assumed physical solar radius
# SOLAR_B0=        3.29094977623 / [deg] S/C tilt of solar north pole
# SOLAR_P0=        10.6352843566 / [deg] S/C celestial north to solar north angle
# SOLAR_EP=        7.21565141559 / [deg] S/C ecliptic north to solar north angle
# CAR_ROT =        2279.42493902 / carrington rotation number
# HGLT_OBS=        3.29094977623 / [deg] S/C heliographic latitude (B0 angle)
# HGLN_OBS=       -16.9805601114 / [deg] S/C heliographic longitude
# CRLT_OBS=        3.29094977623 / [deg] S/C carrington latitude (B0 angle)
# CRLN_OBS=        207.021952092 / [deg] S/C carrington longitude (L0 angle)
# DSUN_OBS=        142533064587. / [m] S/C distance from sun
# DSUN_AU =       0.952774688039 / [AU] S/C distance from sun
# AU_REF  =        149597870700. / [m] assumed physical astronomical unit
# HEEX_OBS=        135487781960. / [m] S/C heliocentric earth ecliptic x
# HEEY_OBS=       -43035363488.6 / [m] S/C heliocentric earth ecliptic y
# HEEZ_OBS=        10329226967.2 / [m] S/C heliocentric earth ecliptic z
# HCIX_OBS=        141222137116. / [m] S/C heliocentric inertial x
# HCIY_OBS=        17465178183.5 / [m] S/C heliocentric inertial y
# HCIZ_OBS=        8182300420.94 / [m] S/C heliocentric inertial z
# HCIX_VOB=       -1229.51172712 / [m/s] S/C heliocentric inertial x velocity
# HCIY_VOB=        20757.3416783 / [m/s] S/C heliocentric inertial y velocity
# HCIZ_VOB=       -2582.78528728 / [m/s] S/C heliocentric inertial z velocity
# HAEX_OBS=        18932069286.7 / [m] S/C heliocentric aries ecliptic x
# HAEY_OBS=        140892578567. / [m] S/C heliocentric aries ecliptic y
# HAEZ_OBS=        10321461039.2 / [m] S/C heliocentric aries ecliptic z
# HEQX_OBS=        136094374412. / [m] S/C heliocentric earth equatorial x
# HEQY_OBS=       -41557739519.1 / [m] S/C heliocentric earth equatorial y
# HEQZ_OBS=        8182300420.94 / [m] S/C heliocentric earth equatorial z
# GSEX_OBS=        11614145495.6 / [m] S/C geocentric solar ecliptic x
# GSEY_OBS=        43035363488.6 / [m] S/C geocentric solar ecliptic y
# GSEZ_OBS=        10329651874.1 / [m] S/C geocentric solar ecliptic z
# OBS_VR  =        1177.01301559 / [m/s] radial velocity of S/C relative to sun
# EAR_TDEL=        15.2400860879 / [s] time(sun to earth) - time(sun to S/C)
# SUN_TIME=        475.439127249 / [s] time(sun to S/C)
# DATE_EAR= '2024-01-01T06:00:22.63' / [UTC] obs. start time corrected to earth
# DATE_SUN= '2024-01-01T05:52:11.95' / [UTC] obs. start time corrected to sun
# DATATYPE=                    1 / data product type
# CAD_END = '757404233:36829'    / OBT at cadence end
# CONF_ID =                    0 / acquisition configuration ID
# MASKRMAX=                  640 / [pixel] max. masking radius
# N       =                56652 / number of octects in the data stream
# CADENCE =               900000 / [ms] acquisition cadence
# OBJ_CNT =                    7 / data object counter
# CAD_BEG = '757403796:65362'    / OBT at cadence start
# IDB_VERS= '        '           /
# HDR_VERS= '5       '           / version of the scientific header
# SNRMIN  =                    0 / [pixel] min. radius for spatial-noise algo
# TSENSOR =       -26.1163005829 / [degC] UVDA temperature
# NB_IMG  =                    1 / number of images in the same data stream
# MASKRMIN=                  264 / [pixel] min. masking radius
# FIRSTROW=                    0 /
# B0_BIN  =                    2 /
# B0_DQ   =                    0 /
# B0_STOP =                 1024 /
# B1_BIN  =                    0 /
# B1_DQ   =                    0 /
# B1_STOP =                    0 /
# B2_BIN  =                    0 /
# B2_DQ   =                    0 /
# B2_STOP =                    0 /
# CHECKSUM= '3l9A6l933l993l99'   / HDU checksum updated 2024-05-22T07:20:28
# DATASUM = '877277568'          / data unit checksum updated 2024-05-22T07:20:28
# INFO_URL= 'http://metis.oato.inaf.it' / link to more information on the instrume

# %% [markdown]
# #### 4.2.2. Images

# %%
fig, axis =  plt.subplots(1, 3, figsize = (14, 5))
fig.supxlabel("x detector")
fig.supylabel("y detector")
fig.suptitle(f"L2 FITS file: {L2[0].header['FILENAME']}")

axis[0].imshow(L2[0].data, norm = LogNorm() )
axis[0].set_title("Visible-light range image")
axis[1].imshow(L2[1].data )
axis[1].set_title("Quality matrix")
axis[2].imshow(L2[2].data, norm = LogNorm() )
axis[2].set_title("Error matrix")
plt.tight_layout()

# %% [markdown]
# ## 5. Comparison

# %% [markdown]
# Let's look closer between another set of L0 and L2 images from the same timestamp.

# %%
L0_A = fits.open(os.path.join("resources", "solo_L0_metis-vl-image_0749705834_V01.fits"))
L2_A = fits.open(os.path.join("resources", "solo_L2_metis-vl-tb_20231004T034235_V01.fits"))

fig, axis = plt.subplots(1, 2, figsize = (10, 5))
fig.suptitle(f"FITS comparison: {L2_A[0].header['FILENAME'][8:35]}")
fig.supxlabel("x detector")
fig.supylabel("y detector")

axis[0].imshow(L0_A[0].data, norm = LogNorm())
axis[0].set_title("L0 Image in Vl")
axis[1].imshow(L2_A[0].data, norm = LogNorm())
axis[1].set_title("L2 Image in Vl")


plt.tight_layout()

# %% [markdown]
# Even though L2 files are more suitable to object detection due to the previous corrections applied, L0 images will be consider first for the Neural Network training. The expected time for obtaining an L2 image may be considerably large therefore it is better to work with L0. In the next steps, corrections may be also applied to the L0 image in order to improve classification and detection.

# %% [markdown]
# ## 6. L0 headers.

# %% [markdown]
# Headers can be downloaded separately from the database server without the needing to download the image itself. Then, it is possible to do a preliminary analysis.

# %%
# Path-to-headers.
PATH_HEADERS_L0 = "resources/metis_all25022025151324.pkl"
headers_l0 = pd.DataFrame(pd.read_pickle(PATH_HEADERS_L0))
print(F"Total files: {len(headers_l0)}, number of headers: {len(headers_l0.columns)}")
# Out:
# Total files: 152455, number of headers: 136

# %%
headers_l0.groupby("orig_x").count()
# Out:
#            id  filename  filepath  file_raw  created  date_obs_start  \
# orig_x
# 1024.0  31653     31653     31653     31653    31653           31653
# 2048.0  78277     78277     78277     78277    78277           78277
# 6496.0      2         2         2         2        2               2
#
#         pubblication_time  obt_end  obt_beg  compress  ...  ttype1  ttype2  \
# orig_x                                                 ...
# 1024.0              31653    31653    31653     31653  ...   31653   31653
# 2048.0              78277    78277    78277     78277  ...   78277   78277
# 6496.0                  2        2        2         2  ...       2       2
#
#         datamin  datamax  width  height    stp  filter    ltp    url
# orig_x
# 1024.0    31653    31653  31653   31653  31653   31653  31653  31653
# 2048.0    78277    78277  78277   78277  78277   78277  78277  78277
# 6496.0        2        2      2       2      2       2      2      2
#
# [3 rows x 135 columns]

# %%
# Display columns.
print(headers_l0.columns.tolist())
# Out:
# ['id', 'filename', 'filepath', 'file_raw', 'created', 'date_obs_start', 'pubblication_time', 'obt_end', 'obt_beg', 'compress', 'comp_rat', 'hdr_vers', 'datatype', 'obj_cnt', 'conf_id', 'sess_num', 'bin_type', 'compr', 'radial', 'cadence', 'cad_beg', 'cad_end', 'apid', 'masking', 'maskrmin', 'maskrmax', 'level', 'origin', 'creator', 'vers_sw', 'version', 'history', 'comment', 'tsensor', 'x_size', 'y_size', 'z_size', 'p_bands', 'n_bands', 'orig_x', 'orig_y', 'firstrow', 'b0_bin', 'b0_dq', 'b0_stop', 'b1_bin', 'b1_dq', 'b1_stop', 'b2_bin', 'b2_dq', 'b2_stop', 'n', 'pol_id', 'measkind', 'framemod', 'vlfpfilt', 'cr_sep', 'cme_obs', 'sundisk', 'sp_noise', 'pmpstab', 'ref_rows', 'ndit', 'snrmin', 'snrmax', 'dac1pol1', 'dac1pol2', 'dac1pol3', 'dac1pol4', 'dac2pol1', 'dac2pol2', 'dac2pol3', 'dac2pol4', 'pmptemp', 'nb_img', 'cr_sep_a', 'cr_sep_b', 'dit', 'n_pol', 'seq_num', 'sn_mean1', 'sn_var1', 'sn_mean2', 'sn_var2', 'sn_mean3', 'sn_var3', 'sn_mean4', 'sn_var4', 'sn_mean5', 'sn_var5', 'presum', 'ndit1', 'ndit2', 'hvu_scr', 'hvu_mcp', 'ref_type', 'ref_hdr', 'ref_cnt', 'r_pol_a', 'r_pol_b', 'r_pol_c', 'r_pol_d', 'cme_rmin', 'cme_rmax', 'cme_limb', 'cme_halo', 'flux', 'prova', 'simple', 'bitpix', 'naxis', 'naxis1', 'naxis2', 'extend', 'longstrn', 'instrume', 'blank', 'datasum', 'checksum', 'xtension', 'pcount', 'gcount', 'tfields', 'extname', 'tform1', 'tform2', 'ttype1', 'ttype2', 'datamin', 'datamax', 'width', 'height', 'stp', 'filter', 'ltp', 'url']

# %% [markdown]
# ### 6.1. Headers analysis.

# %% [markdown]
# #### 6.1.1. Acquisition time

# %%
# Compute acquisition time.
headers_l0["acquisition time"] = headers_l0.apply(lambda x: x["obt_end"] - x["obt_beg"], axis = 1)
# Convert into minutes.
acq_time = headers_l0["acquisition time"].apply(lambda x: x/60).to_list()

fig, axis = plt.subplots(1, 1, figsize= (13, 4))
axis.hist(acq_time, color = "black")
axis.set_title("Distribution of acquisition time in metis FITS files.")
axis.set_xlabel("Minutes"), axis.set_ylabel("Number of FITS")
# Out:
# (Text(0.5, 0, 'Minutes'), Text(0, 0.5, 'Number of FITS'))

# %% [markdown]
# Most FITS files have 1 minute of acquisition time.

# %% [markdown]
# #### 6.1.2. Datatype

# %%
# Create new column from the "file raw" column and extract the datatype
headers_l0["datapack"] = headers_l0["file_raw"].apply(lambda x: x[-12:-4])

# Count the number of datapacks.
data_packs = headers_l0.groupby("datapack").count()["id"].to_dict()
labels = list(data_packs.keys())
counts = list(data_packs.values())

# %%
fig, axis = plt.subplots(1, 1, figsize = (10, 5))
a = axis.bar(labels, counts, color = "black")
axis.set_title("Datatype distribution in L0 fits.")
axis.set_ylabel("Number of FITS")
axis.set_xlabel("datatypes")
axis.bar_label(a)
# Out:
# [Text(0, 0, '12'),
#  Text(0, 0, '18807'),
#  Text(0, 0, '36682'),
#  Text(0, 0, '93097'),
#  Text(0, 0, '3857')]

# %% [markdown]
# Most of the FITS L0 are images in the visible light range.

# %% [markdown]
# #### 6.1.3. Original size of FITS

# %%
# Keep VL and UV images.
images_headers_l0 = headers_l0[(headers_l0["datapack"] == "UV_IMAGE") | (headers_l0["datapack"] == "VL_IMAGE")]

# Group by sizes.
sizes_l0 = images_headers_l0.groupby(["width", "height", "datapack"]).count()["id"].to_dict()
labels = [str(sizes)[1:-2] for sizes in list(sizes_l0.keys())]
fig, axis = plt.subplots(1, 1, figsize = (25, 5))
a = axis.bar(labels, list(sizes_l0.values()), color = "black")
axis.bar_label(a)
axis.set_title("L0 FITS size distribution for VL and UV")
axis.set_xlabel("Sizes")
axis.set_ylabel("Number of files")
# Out:
# Text(0, 0.5, 'Number of files')

# %% [markdown]
# Even though L0 FITS images have different original sizes, all the images are normalized in this way:

# %%
headers_l0.groupby("orig_x").count()
# Out:
#            id  filename  filepath  file_raw  created  date_obs_start  \
# orig_x
# 1024.0  31653     31653     31653     31653    31653           31653
# 2048.0  78277     78277     78277     78277    78277           78277
# 6496.0      2         2         2         2        2               2
#
#         pubblication_time  obt_end  obt_beg  compress  ...  datamin  datamax  \
# orig_x                                                 ...
# 1024.0              31653    31653    31653     31653  ...    31653    31653
# 2048.0              78277    78277    78277     78277  ...    78277    78277
# 6496.0                  2        2        2         2  ...        2        2
#
#         width  height    stp  filter    ltp    url  acquisition time  datapack
# orig_x
# 1024.0  31653   31653  31653   31653  31653  31653             31653     31653
# 2048.0  78277   78277  78277   78277  78277  78277             78277     78277
# 6496.0      2       2      2       2      2      2                 2         2
#
# [3 rows x 137 columns]

# %% [markdown]
# Then some images were binned in order to have an uniform size. In this case, vl images are 2048x2048 and uv are 1024x1024.

# %% [markdown]
# Here, we will plot images with different sizes.

# %% [markdown]
# **Display images VL**

# %%
# Select random images with different sizes.
sampleA = list(images_headers_l0[
    (images_headers_l0["datapack"] == "VL_IMAGE") 
    & (images_headers_l0["width"] == 1024.0)
    & (images_headers_l0["height"] == 1024.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())

sampleB = list(images_headers_l0[
    (images_headers_l0["datapack"] == "VL_IMAGE") 
    & (images_headers_l0["width"] == 512.0)
    & (images_headers_l0["height"] == 512.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())
sampleC = list(images_headers_l0[
    (images_headers_l0["datapack"] == "VL_IMAGE") 
    & (images_headers_l0["width"] == 2048.0)
    & (images_headers_l0["height"] == 2048.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())

# %%
# Download images.
download_fits(sampleA[0], sampleA[1], "resources/random samples VL")
download_fits(sampleB[0], sampleB[1], "resources/random samples VL")
download_fits(sampleC[0], sampleC[1], "resources/random samples VL")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Download images.
# ----> 2 download_fits(sampleA[0], sampleA[1], "resources/random samples VL")
#       3 download_fits(sampleB[0], sampleB[1], "resources/random samples VL")
#       4 download_fits(sampleC[0], sampleC[1], "resources/random samples VL")
#
# File ~/University of Padua/thesis/METIS/libraries/utilities.py:71, in download_fits(url, filename, folder, timeout)
#      62 def download_fits(url, filename, folder, timeout = 5):
#      63     """Download a fits file and save it in a specific path.
#      64
#      65     Parameters:
#    (...)
#      68         folder (str): directory where file will be stored.
#      69     """
# ---> 71     with urllib.request.urlopen(url, timeout=timeout) as response, open(os.path.join(folder, filename), 'wb') as out_file:
#      72             out_file.write(response.read())
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
fig, axis = plt.subplots(1, 3, figsize = (15,5))
folder = os.listdir("resources/random samples VL")
for idx, files in enumerate(folder):
    fits_file = fits.open(os.path.join("resources/random samples VL",files))
    axis[idx].imshow(fits_file[0].data)
    axis[idx].set_title(fits_file[0].header["FILENAME"] + "\n" + str(fits_file[0].header["NAXIS1"]) +
                        " " + str( fits_file[0].header["NAXIS2"]))
    
    if idx ==2:
        break

# %% [markdown]
# Despite in headers information it says images have 512, 1024 and 2048 respectively, it appears the real size is 2048 x 2048.

# %% [markdown]
# **Display images UV**

# %%
sampleA = list(images_headers_l0[
    (images_headers_l0["datapack"] == "UV_IMAGE") 
    & (images_headers_l0["width"] == 1024.0)
    & (images_headers_l0["height"] == 1024.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())

sampleB = list(images_headers_l0[
    (images_headers_l0["datapack"] == "UV_IMAGE") 
    & (images_headers_l0["width"] == 512.0)
    & (images_headers_l0["height"] == 512.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())
sampleC = list(images_headers_l0[
    (images_headers_l0["datapack"] == "UV_IMAGE") 
    & (images_headers_l0["width"] == 256.0)
    & (images_headers_l0["height"] == 256.0)
    ].sample(1)[["url", "filename"]].reset_index(drop=True).iloc[0].to_dict().values())

# %%
# Download samples.
download_fits(sampleA[0], sampleA[1], "resources/random samples UV")
download_fits(sampleB[0], sampleB[1], "resources/random samples UV")
download_fits(sampleC[0], sampleC[1], "resources/random samples UV")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Download samples.
# ----> 2 download_fits(sampleA[0], sampleA[1], "resources/random samples UV")
#       3 download_fits(sampleB[0], sampleB[1], "resources/random samples UV")
#       4 download_fits(sampleC[0], sampleC[1], "resources/random samples UV")
#
# File ~/University of Padua/thesis/METIS/libraries/utilities.py:71, in download_fits(url, filename, folder, timeout)
#      62 def download_fits(url, filename, folder, timeout = 5):
#      63     """Download a fits file and save it in a specific path.
#      64
#      65     Parameters:
#    (...)
#      68         folder (str): directory where file will be stored.
#      69     """
# ---> 71     with urllib.request.urlopen(url, timeout=timeout) as response, open(os.path.join(folder, filename), 'wb') as out_file:
#      72             out_file.write(response.read())
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/miniconda3/envs/python_gpu/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
fig, axis = plt.subplots(1, 3, figsize = (15,5))
folder = os.listdir("resources/random samples UV")
for idx, files in enumerate(folder):
    fits_file = fits.open(os.path.join("resources/random samples UV",files))
    axis[idx].imshow(fits_file[0].data)
    axis[idx].set_title(fits_file[0].header["FILENAME"] + "\n" + str(fits_file[0].header["NAXIS1"]) +
                        " " + str( fits_file[0].header["NAXIS2"]))
    
    if idx == 2:
        break

# %% [markdown]
# Despite in headers information it says images have 256, 512, 1024 respectively, it appears the real size is 1024 x 1024.

# %% [markdown]
# Given that the sizes given in the headers of the repository does not coincides with the real ones, it is better to extract manually from each file.

# %% [markdown]
# #### 6.1.4. Detector integration time

# %% [markdown]
# Taking into account the following information:
#
# 1. **dit** -> detector integration time in ms
# 2. **ndit** -> number of averaged frames in VL data products.
# 3. **ndit1** -> number of hardware-averaged frames in UV data products and PCU acc. matrices.
# 4. **ndit2** -> number of averaged frames in UV data products.

# %% [markdown]
# The total exposure time will be:
#
# (detector integration time) * (number of averaged frames)

# %%
# Compute total exposure time, take into account that ndit is for vl images and ndit1 and ndit2 for uv images.
images_headers_l0["exposure_time"] = images_headers_l0.apply(
    lambda x: x["dit"] * x["ndit"] / 1000 if not pd.isna(x["ndit"]) else x["dit"] *x["ndit1"] * x["ndit2"] / 1000,
    axis=1
)
# Out:
# /tmp/ipykernel_17819/1487388755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   images_headers_l0["exposure_time"] = images_headers_l0.apply(

# %%
fig, axis = plt.subplots(2, 1, figsize = (13, 8))
fig.supxlabel("Total exposure time (dit*frames)"), fig.supylabel("Number of images")
a = axis[0].hist(images_headers_l0[images_headers_l0["datapack"] == "VL_IMAGE"]["exposure_time"].to_list(), bins =20, color ="black")
axis[0].set_title("Exposure time in VL images", fontsize = 9)
b = axis[1].hist(images_headers_l0[images_headers_l0["datapack"] == "UV_IMAGE"]["exposure_time"].to_list(), bins =20, color = "black")
axis[1].set_title("Exposure time in UV images", fontsize = 9)
# Out:
# Text(0.5, 1.0, 'Exposure time in UV images')

# %% [markdown]
# Save new information.

# %%
images_headers_l0.to_pickle("l0_headers_refined.pkl")

# %%
# Generate .csv with links, stp and ltp of each L0 image in the visible light bandwidth.
images_headers_l0[images_headers_l0["datapack"] == "VL_IMAGE.raw"][["ltp", "stp", "url"]].reset_index(drop = True).to_csv("l0_fits_urls_vl.csv", index= False)
images_headers_l0[images_headers_l0["datapack"] == "UV_IMAGE.raw"][["ltp", "stp", "url"]].reset_index(drop = True).to_csv("l0_fits_urls_uv.csv", index= False)
